# %%
import duckdb

con = duckdb.connect()
file_path = '/home/gnart/dev/faa/stables-analytics/.data/open_logs_260122_24251873_24287161.parquet'

# Option 1: Create a view
con.execute(f"\
    CREATE VIEW logs \
        AS SELECT * FROM \
            '{file_path}'")

# %%
con.sql("SELECT COUNT(*) FROM logs").show()
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │          253 │
# └──────────────┘
